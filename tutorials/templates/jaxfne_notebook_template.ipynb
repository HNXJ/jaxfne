# %% [markdown]
# # JAXFNE Notebook Template
#
# This notebook demonstrates the canonical jaxfne workflow:
# configure → construct → simulate → optimize → visualize → export.
#
# ## Scope Gates
# - **truth_mode:** `truth_safe_unverified`
# - **claim_level:** `computational_scaffold`
# - **field_solver_status:** `laminar_proxy_no_pde`
# - **physical_amplitude_claim_allowed:** `False`

# %% [markdown]
# ## Installation & Setup

# %%
# !pip install -q jaxfne

# %% [markdown]
# ## Development Branch (Optional)
#
# Run this cell to test the current `dev` branch.

# %%
# !pip install -q "jaxfne @ git+https://github.com/HNXJ/jaxfne.git@dev"

# %% [markdown]
# ## Imports & Environment Setup

# %%
import os, json
from pathlib import Path
import jaxfne as jtfne
print(f"jaxfne version: {jtfne.__version__}")

# %% [markdown]
# SEED = 42
# DURATION_MS = 1000.0
# DT_MS = 0.1
# cfg = jtfne.default_spectrolaminar_config(seed=SEED, duration_ms=DURATION_MS, dt_ms=DT_MS)

# %%
# Runtime configuration
SEED = 42
DURATION_MS = 1000.0
DT_MS = 0.1
N_NEURONS = 100

# Create configuration
cfg = jtfne.default_spectrolaminar_config(
    n_per_area=N_NEURONS,
    seed=SEED,
    duration_ms=DURATION_MS,
    dt_ms=DT_MS
)

# %% [markdown]
# ## Model Construction & Simulation

# %%
model = jtfne.construct(cfg)
print(f"✓ Model constructed: {model.summary()['n_units']} neurons

# %% [markdown]
# ## Workflow Steps
#
# Add your simulation, optimization, and visualization steps here.

# %% [markdown]
# ## Next Steps
#
# 1. **Simulation:** Use `model.simulate()` to run the baseline.
# 2. **Optimization:** Define an objective and optimizer, use `model.tune()`.
# 3. **Visualization:** Use `jtfne.vis.*` to visualize results.
# 4. **Export:** Save artifacts as JSON with metadata and asset hashes.
