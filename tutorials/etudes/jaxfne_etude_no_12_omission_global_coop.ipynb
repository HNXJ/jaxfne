# %% [markdown]
# # jaxfne — Étude No. 12 · Omission — Global (COOP)
#
# > **STATUS: TO BE IMPLEMENTED (placeholder).**
#
# Global/contextual omission prediction (COOP).
#
# ## Plan
#
# - **Goal.** Global-level omission / contextual-omission prediction (**COOP**): omission defined by the *global* sequence context rather than the local train. Tests context-dependent predictive signaling across the hierarchy.
# - **Building blocks:** multi-area network (Étude 6) + global oddball structure (Étude 10) + omission events (Étude 11), run as continuous adaptation (Étude 8).
# - **Outputs:** global-omission response localized to deep/feedback layers and higher areas; dissociation from local omission (Étude 11).
# - **Note:** this is the capstone — depends on Études 6–11 being in place.
#
# ## Builds on
#
# - Étude 5 (enhanced biophysical column) and earlier études in this series.
#
# ## Truth
#
# Computational scaffold; `*_proxy` readouts only; truth gates stay at conservative defaults. No physical/validated/mechanism claims without receipts + nulls/ablations.

# %%
import jaxfne as jtfne
# Étude No. 12: Omission — Global (COOP)
# Skeleton only — implementation pending (see plan above).
raise NotImplementedError("Étude No. 12 (Omission — Global (COOP)) is a planned placeholder.")
