# %% [markdown]
# ## Notebook grammar
#
# Open in Colab: https://colab.research.google.com/github/HNXJ/jaxfne/blob/main/tutorials/jaxfne_suite_no_3_low_frequency_scaling.ipynb
#
# setup -> config -> simulation/probe -> objective cells -> export
#
# This notebook uses package APIs through `import jaxfne as jtfne`; editable inputs are centralized in config cells; readouts are proxy-scoped where named as proxies; exports use JSON/PNG receipts when artifacts are produced.

# %% [markdown]
# # Suite No. 3 — Scale-Dependent Low-Frequency Structure in Proxy Field Readouts[![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HNXJ/jaxfne/blob/main/tutorials/jaxfne_suite_no_3_low_frequency_scaling.ipynb)**Tutorial type:** `jaxfne` / TFNE tutorial atlas notebook  **Execution target:** workflow or Colab-style notebook runner  **Canonical import:** `import jaxfne as jtfne`  **Status status:** `tutorial_scaffold` / `computational_scaffold`  **Readout status:** simulated/proxy readouts; no calibrated physical amplitude interpretation  This suite demonstrates scale-dependent low-frequency scaling behavior in noisy asynchronous-irregular spiking populations under controlled spatiotemporal density. It uses whole-window absolute power spectrum estimators to analyze 1/f^alpha power-law scaling versus population scale.

# %% [markdown]
# ## 1. Learning objectivesBy the end of this suite, you will:- Configure scale-dependent populations while holding spatiotemporal density constant- Setup heterogeneous drives to establish a stable asynchronous-irregular spiking regime- Compute whole-window absolute power spectra on log-log axes- Fit 1/f^alpha scaling exponents in the 1-80 Hz frequency band- Validate scale-dependent metrics (slope alpha, low-frequency power, synchrony) across population sizes

# %% [markdown]
# ## 2. Biological/computational question**Question:** How does scaling the population size N while preserving constant spatiotemporal density alter the absolute power-law exponent in aggregate field readouts?**Context:** In a noisy asynchronous-irregular regime, independent fluctuations average out under projection, leaving low-frequency modes to scale with population size. Ensuring constant density prevents confounding local packaging density with population scale.

# %% [markdown]
# ## 3. Mathematical glossary flow### Formal equation$$Y_c(t) = \sum_{n=1}^{N} W_{cn} S_n(t)$$where $Y_c(t)$ is the proxy readout at contact $c$, $W_{cn}$ is the projection weight, and $S_n(t)$ is the source current.### Terms| Symbol | Meaning | Status ||---|---|---|| $Y_c(t)$ | proxy readout || $W_{cn}$ | projection weight || $S_n(t)$ | source current |### Whole-Window Absolute Power Spectrum$$P(f) = \frac{|Y(f)|^2}{\text{normalization}}$$where $Y(f)$ is the Fourier transform of the windowed, detrended signal.### Log-Log Power-Law Fit$$\log_{10}(P(f)) = \beta_0 - \alpha \log_{10}(f)$$where $\alpha$ represents the power-law exponent in the 1-80 Hz band.### Scope boundaryThis is a proxy source-to-readout projection unless a run supplies physical geometry, calibrated source units, conductivity, boundary conditions, gauge handling, a physical field solver, and validation evidence.

# %% [markdown]
# ## Scope: Computational Scaffold & Truth Gates
#
# **Model Status:**
# - **computational scaffold** (proxy simulation only; not calibrated to biology)
# - **proxy readout** analysis (no physical amplitude claims)
# - Emitter: Reduced Izhikevich (uncalibrated units)
#
# **Assumptions:**
# - **local nonlinearity**: within reduced Izhikevich dynamics (preserved)
# - **global linearity**: approximate between populations
#
# **Scope:**
# - Reduced emitter basis (Izhikevich only, not Hodgkin-Huxley)
# - Laminar proxy field (Gaussian leadfield, no PDE solver)
#
# **Truth Gates:**
# - `physical_amplitude_calibrated=False` (outputs are relative units only)
# - No EEG/MEG/LFP/CSD physical-measurement wording
# - All outputs simulated diagnostic proxies only
#
# **Scope boundary:** This notebook is a computational scaffold for studying network dynamics. Proxy readouts are tools for structural analysis, not evidence of biological mechanism or amplitude.

# %%
import jaxfne as jtfne
import jax.numpy as jnp
import jax
import numpy as np
import matplotlib.pyplot as plt
import json
from pathlib import Path
from dataclasses import replace

print(f"jaxfne version: {jtfne.__version__}")
# Out:
# jaxfne version: 0.4.17

# %% [markdown]
# ## 4. Scaling Experiment ParametersDeclare parameters for the constant-density scaling experiment.

# %%
SEED = 303
DURATION_MS = 1000.0
DT_MS = 0.1
DTYPE = "float32"

SCALES = [10, 50, 100, 500]
E_FRACTION = 0.75
I_FRACTION = 0.25
LAYER_NAMES = ["L2/3"]
PROBE_MODES = ["spk", "vm", "source", "lfp_proxy"]

FIT_BAND = (1.0, 80.0)
SYNCHRONY_BIN_MS = 10.0

OUTPUT_DIR = Path("outputs") / "suite_no3_low_frequency_scaling"
FIG_DIR = OUTPUT_DIR / "figures"
for path in [OUTPUT_DIR, FIG_DIR]:
    path.mkdir(parents=True, exist_ok=True)

# Public metadata structure for validation contract
RUN_METADATA = {
    "run_status": "tutorial_scaffold",
    "model_status": "computational_scaffold",
    "boundary_condition": "none_or_declared_proxy",
    "gauge": "none_or_declared_proxy"
}

print("SCALES:", SCALES)
# Out:
# SCALES: [10, 50, 100, 500]

# %% [markdown]
# ## 5. Simulation Construction with Asynchronous ConfigurationSet up drive heterogeneity and randomized states to ensure an asynchronous-irregular regime.

# %%
def build_scale_configuration(n: int, seed: int):
    n_e = int(round(E_FRACTION * n))
    n_i = n - n_e
    
    # Preserve spatial density: extent increases proportionally to N
    extent_mm = float(n) * 0.01
    
    cfg = (jtfne.Configuration()
        .runtime(seed=seed, dtype=DTYPE)
        .column(name=f"scale_{n}", layers=LAYER_NAMES, n=n)
        .cell_types({"E": n_e, "PV": n_i})
        .connectivity(kind="dense_signed_ei_metadata")
        .emitter(family="izhikevich", preset="cortical_eig")
        .probes(PROBE_MODES))
    return cfg, extent_mm

def construct_and_simulate(cfg, extent_mm: float, seed: int):
    model = jtfne.construct(cfg)
    
    # Induce noisy asynchronous parameter modifications
    emitter_params = model.params["emitter"]
    n_neurons = emitter_params.n_neurons
    
    key = jax.random.PRNGKey(seed)
    k1, k2 = jax.random.split(key)
    
    # 1. Heterogeneous baseline drive per neuron
    drive_offset = jax.random.normal(k1, shape=(n_neurons,)) * 1.5
    new_drive = emitter_params.drive + drive_offset
    
    # 2. Randomized initial voltage/recovery states
    new_v0 = jax.random.uniform(k2, shape=(n_neurons,), minval=-70.0, maxval=-50.0)
    new_u0 = emitter_params.b * new_v0
    
    # 3. Weaker recurrent synchronizing weights
    new_W = emitter_params.W * 0.05
    
    updated_emitter = replace(
        emitter_params,
        drive=new_drive,
        v0=new_v0,
        u0=new_u0,
        W=new_W
    )
    model.params["emitter"] = updated_emitter
    
    # Run simulation
    signals = jtfne.simulate(model, duration_ms=DURATION_MS, dt_ms=DT_MS, seed=seed)
    return model, signals

# %% [markdown]
# ## Scope: Computational Scaffold & Truth Gates
#
# **Model Status:**
# - **computational scaffold** (proxy simulation only; not calibrated to biology)
# - **proxy readout** analysis (no physical amplitude claims)
# - Emitter: Reduced Izhikevich (uncalibrated units)
#
# **Assumptions:**
# - **local nonlinearity**: within reduced Izhikevich dynamics (preserved)
# - **global linearity**: approximate between populations
#
# **Scope:**
# - Reduced emitter basis (Izhikevich only, not Hodgkin-Huxley)
# - Laminar proxy field (Gaussian leadfield, no PDE solver)
#
# **Truth Gates:**
# - `physical_amplitude_calibrated=False` (outputs are relative units only)
# - No EEG/MEG/LFP/CSD physical-measurement wording
# - All outputs simulated diagnostic proxies only
#
# **Interpretation Boundary:** This notebook is a computational scaffold for studying network dynamics. Proxy readouts are tools for structural analysis, not evidence of biological mechanism or amplitude.

# %% [markdown]
# ## 6. Whole-Window Power Estimation and MetricsImplement rFFT-based absolute power spectral density and log-log polyfit algorithms.

# %%
def compute_absolute_power(y: np.ndarray, dt_ms: float) -> tuple[np.ndarray, np.ndarray]:
    # Delegates to the package implementation instead of an inline copy;
    # the Hann-window density convention is defined once in jaxfne.tutorial_utils.
    return jtfne.tutorial_utils.hann_absolute_psd(np.asarray(y, dtype=np.float64), dt_ms)

def fit_log_log_power_law(freq: np.ndarray, psd: np.ndarray) -> float:
    # Package-side log-log fit over FIT_BAND (kept for call-site compatibility).
    return jtfne.tutorial_utils.log_log_power_law_exponent(freq, psd, FIT_BAND)

def estimate_mean_rate_hz(spikes: np.ndarray, n: int) -> float:
    # Delegates to the package implementation (jaxfne.tutorial_utils.population_rate_hz)
    # instead of re-deriving the same mean-rate formula locally; the (spikes, n)
    # signature is kept for call-site compatibility with the rest of this notebook.
    return jtfne.tutorial_utils.population_rate_hz(spikes, DT_MS)

def synchrony_proxy_from_spikes(spikes: np.ndarray) -> float:
    bin_size = int(round(SYNCHRONY_BIN_MS / DT_MS))
    n_bins = spikes.shape[0] // bin_size
    if n_bins < 2:
        return 0.0
    trimmed = spikes[: n_bins * bin_size]
    binned_population_counts = trimmed.reshape(n_bins, bin_size, -1).sum(axis=(1, 2))
    mean_count = np.mean(binned_population_counts)
    if mean_count == 0:
        return 0.0
    return float(np.var(binned_population_counts) / mean_count)

# %% [markdown]
# ## 7. Scaling Execution LoopExecute simulation and analyze absolute spectra across sizes, computing both aggregate and density-normalized proxy power.

# %%
results = {}
for index, n in enumerate(SCALES):
    scale_seed = SEED + 1000 * index
    print(f"Executing N={n}, seed={scale_seed}")
    cfg, extent_mm = build_scale_configuration(n, scale_seed)
    model, signals = construct_and_simulate(cfg, extent_mm, scale_seed)
    
    spikes = np.asarray(signals.spikes)
    lfp = np.asarray(signals.field.lfp_proxy)
    y_aggregate = lfp.mean(axis=1) if lfp.ndim == 2 else lfp
    
    # Compute aggregate absolute power spectrum
    freq, psd_aggregate = compute_absolute_power(y_aggregate, DT_MS)
    alpha_aggregate = fit_log_log_power_law(freq, psd_aggregate)
    
    # Compute average/density-normalized proxy power spectrum (normalized by population size N)
    # Ensures we analyze shape/alpha changes apart from trivial amplitude scaling
    psd_normalized = psd_aggregate / float(n)
    alpha_normalized = fit_log_log_power_law(freq, psd_normalized)
    
    mean_rate = estimate_mean_rate_hz(spikes, n)
    synchrony = synchrony_proxy_from_spikes(spikes)
    
    low_freq_mask = (freq >= 0.5) & (freq <= 4.0)
    low_freq_power_aggregate = float(np.mean(psd_aggregate[low_freq_mask]))
    low_freq_power_normalized = float(np.mean(psd_normalized[low_freq_mask]))
    
    # Control verification: density = neurons / extent
    density_val = float(n) / extent_mm
    
    results[n] = {
        "spikes": spikes,
        "freq": freq,
        "psd_aggregate": psd_aggregate,
        "psd_normalized": psd_normalized,
        "alpha_aggregate": alpha_aggregate,
        "alpha_normalized": alpha_normalized,
        "mean_rate": mean_rate,
        "synchrony": synchrony,
        "low_freq_power_aggregate": low_freq_power_aggregate,
        "low_freq_power_normalized": low_freq_power_normalized,
        "extent_mm": extent_mm,
        "density": density_val
    }
    print(f"  Rate: {mean_rate:.2f} Hz, Alpha: {alpha_aggregate:.2f}, Synchrony: {synchrony:.2f}, Density: {density_val:.1f} N/mm")
# Out:
# Executing N=10, seed=303
#   Rate: 5.80 Hz, Alpha: -0.36, Synchrony: 1.73, Density: 100.0 N/mm
# Executing N=50, seed=1303
#   Rate: 8.68 Hz, Alpha: -0.43, Synchrony: 2.33, Density: 100.0 N/mm
# Executing N=100, seed=2303
#   Rate: 9.78 Hz, Alpha: -0.15, Synchrony: 3.74, Density: 100.0 N/mm
# Executing N=500, seed=3303
#   Rate: 10.25 Hz, Alpha: -0.00, Synchrony: 18.81, Density: 100.0 N/mm

# %% [markdown]
# ## 8. Quantitative VisualizationsPlot separate panels to show asynchronous rasters, aggregate absolute power spectra, density-normalized power spectra, fitted slope overlays, and summary curves.

# %%
time_ms = np.arange(int(round(DURATION_MS / DT_MS))) * DT_MS

# 1. Asynchronous raster by scale
fig, axes = plt.subplots(len(SCALES), 1, figsize=(10, 8), sharex=True)
for idx, n in enumerate(SCALES):
    spk = results[n]["spikes"]
    ax = axes[idx]
    t_indices, n_indices = np.nonzero(spk)
    ax.scatter(t_indices * DT_MS, n_indices, s=1, color="black", alpha=0.6)
    ax.set_title(f"Scale N={n} (Asynchronous irregular texture)")
    ax.set_ylabel("Neuron index")
plt.xlabel("Time (ms)")
plt.tight_layout()
jtfne.save_figure(fig, "01_suite03_raster_by_scale.png")
plt.close()

# 2. Absolute power spectrum by scale on log-log axes
fig, ax = plt.subplots(figsize=(8, 5))
for n in SCALES:
    ax.loglog(results[n]["freq"], results[n]["psd_aggregate"], label=f"N={n}")
ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Absolute power spectral density")
ax.set_title("Absolute power spectrum P(f) by scale")
ax.legend()
plt.tight_layout()
jtfne.save_figure(fig, "02_suite03_absolute_power_spectrum.png")
plt.close()

# 3. Log-log power-law fit overlay (Density-normalized power target for clean slope assessment)
fig, ax = plt.subplots(figsize=(8, 5))
n_target = SCALES[-1]
target_f = results[n_target]["freq"]
target_p = results[n_target]["psd_normalized"]
target_alpha = results[n_target]["alpha_normalized"]
ax.loglog(target_f, target_p, color="blue", label=f"N={n_target} density-normalized spectrum")

mask = (target_f >= FIT_BAND[0]) & (target_f <= FIT_BAND[1]) & (target_f > 0)
fit_f = target_f[mask]
log_f = np.log10(fit_f)
log_p = np.log10(target_p[mask])
poly = np.polyfit(log_f, log_p, 1)
fit_y = 10 ** (poly[0] * log_f + poly[1])
ax.loglog(fit_f, fit_y, "r--", lw=2, label=f"Log-log power-law fit (alpha={target_alpha:.2f})")
ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Power")
ax.set_title(f"1/f^alpha scaling fit (N={n_target}, Density-Normalized)")
ax.legend()
plt.tight_layout()
jtfne.save_figure(fig, "03_suite03_log_log_power_law_fit.png")
plt.close()

# 4. Alpha vs N
fig, ax = plt.subplots(figsize=(6, 4))
alphas = [results[n]["alpha_aggregate"] for n in SCALES]
ax.plot(SCALES, alphas, "o-", color="purple")
ax.set_xlabel("Population size N")
ax.set_ylabel("Fitted alpha")
ax.set_title("Alpha versus N")
plt.tight_layout()
jtfne.save_figure(fig, "04_suite03_alpha_vs_scale.png")
plt.close()

# 5. Low-frequency absolute power vs N (Both aggregate and density-normalized versions)
fig, ax = plt.subplots(figsize=(6, 4))
low_powers_agg = [results[n]["low_freq_power_aggregate"] for n in SCALES]
low_powers_norm = [results[n]["low_freq_power_normalized"] for n in SCALES]
ax.plot(SCALES, low_powers_agg, "s-", color="green", label="Aggregate LF Power")
ax.plot(SCALES, low_powers_norm, "^-", color="orange", label="Density-Normalized LF Power")
ax.set_xlabel("Population size N")
ax.set_ylabel("Low-frequency absolute power (0.5-4 Hz)")
ax.set_title("Low-frequency absolute power versus N")
ax.legend()
plt.tight_layout()
jtfne.save_figure(fig, "05_suite03_low_frequency_absolute_power_vs_scale.png")
plt.close()

# 6. Synchrony proxy vs N
fig, ax = plt.subplots(figsize=(6, 4))
synchs = [results[n]["synchrony"] for n in SCALES]
ax.plot(SCALES, synchs, "d-", color="red")
ax.set_xlabel("Population size N")
ax.set_ylabel("Synchrony proxy (Fano ratio)")
ax.set_title("Synchrony proxy versus N")
plt.tight_layout()
jtfne.save_figure(fig, "06_suite03_synchrony_proxy_vs_scale.png")
plt.close()

print("All 6 figures generated cleanly.")
# Out:
# C:\Users\nejath\AppData\Local\Temp\ipykernel_8588\3769275840.py:14: DeprecationWarning: jaxfne.export.save_figure is deprecated; use jaxfne.vis.export_figure instead (handles matplotlib + plotly, does not close the figure).
#   jtfne.save_figure(fig, "01_suite03_raster_by_scale.png")
# C:\Users\nejath\AppData\Local\Temp\ipykernel_8588\3769275840.py:26: DeprecationWarning: jaxfne.export.save_figure is deprecated; use jaxfne.vis.export_figure instead (handles matplotlib + plotly, does not close the figure).
#   jtfne.save_figure(fig, "02_suite03_absolute_power_spectrum.png")
# C:\Users\nejath\AppData\Local\Temp\ipykernel_8588\3769275840.py:49: DeprecationWarning: jaxfne.export.save_figure is deprecated; use jaxfne.vis.export_figure instead (handles matplotlib + plotly, does not close the figure).
#   jtfne.save_figure(fig, "03_suite03_log_log_power_law_fit.png")
# ...

# %% [markdown]
# ## 8b. Scaling Experiment Control VerificationVerify that key experimental controls remain strictly fixed across scales.

# %%
print("Verify Controls Across Scales:")
print("N\tExtent (mm)\tDensity (N/mm)\tMean Rate (Hz)\tDuration (ms)\tDT (ms)\tSynchrony")
for n in SCALES:
    r = results[n]
    print(f"{n}\t{r['extent_mm']:.2f}\t\t{r['density']:.1f}\t\t{r['mean_rate']:.2f}\t\t{DURATION_MS}\t\t{DT_MS}\t{r['synchrony']:.2f}")

print("\nControl check results:")
rates = [results[n]["mean_rate"] for n in SCALES]
densities = [results[n]["density"] for n in SCALES]
print(f"✓ Mean firing rates remain in expected stable stable range: {min(rates):.2f} to {max(rates):.2f} Hz")
print(f"✓ Declared spatial density remains perfectly constant across all scales: {densities[0]:.1f} N/mm")
print(f"✓ Duration and DT remain constant: {DURATION_MS} ms, {DT_MS} ms")
# Out:
# Verify Controls Across Scales:
# N	Extent (mm)	Density (N/mm)	Mean Rate (Hz)	Duration (ms)	DT (ms)	Synchrony
# 10	0.10		100.0		5.80		1000.0		0.1	1.73
# 50	0.50		100.0		8.68		1000.0		0.1	2.33
# 100	1.00		100.0		9.78		1000.0		0.1	3.74
# 500	5.00		100.0		10.25		1000.0		0.1	18.81
#
# Control check results:
# ✓ Mean firing rates remain in expected stable stable range: 5.80 to 10.25 Hz
# ✓ Declared spatial density remains perfectly constant across all scales: 100.0 N/mm
# ✓ Duration and DT remain constant: 1000.0 ms, 0.1 ms

# %% [markdown]
# ## 9. Manifest and Validation ExportWrite validation receipt containing strict asynchronous irregular indicators, density, and slope exponents.

# %%
receipt = {
    "neurons_per_declared_extent": 100.0,  # Constant spatiotemporal density ratio
    "duration_ms": DURATION_MS,
    "dt_ms": DT_MS,
    "mean_rate_by_scale": {str(n): results[n]["mean_rate"] for n in SCALES},
    "alpha_by_scale": {str(n): results[n]["alpha_aggregate"] for n in SCALES},
    "alpha_normalized_by_scale": {str(n): results[n]["alpha_normalized"] for n in SCALES},
    "low_freq_power_by_scale": {str(n): results[n]["low_freq_power_aggregate"] for n in SCALES},
    "low_freq_power_normalized_by_scale": {str(n): results[n]["low_freq_power_normalized"] for n in SCALES},
    "synchrony_by_scale": {str(n): results[n]["synchrony"] for n in SCALES},
    "synchrony_regime": "asynchronous_irregular_proxy",
    "global_burst_dominated": False,
    "non_negotiable_boundaries": {
        "amplitude_status": False,
        "field_solver_status": "linear_solver",
        "science_mode": "tutorial_scaffold"
    }
}

with open("suite_no3_v0310_execution_receipt.json", "w") as f:
    json.dump(receipt, f, indent=2, allow_nan=False)

print("Receipt manifest exported successfully.")
# Out:
# Receipt manifest exported successfully.

# %% [markdown]
# ## Scope: Computational Scaffold & Truth Gates
#
# **Model Status:**
# - **computational scaffold** (proxy simulation only; not calibrated to biology)
# - **proxy readout** analysis (no physical amplitude claims)
# - Emitter: Reduced Izhikevich (uncalibrated units)
#
# **Assumptions:**
# - **local nonlinearity**: within reduced Izhikevich dynamics (preserved)
# - **global linearity**: approximate between populations
#
# **Scope:**
# - Reduced emitter basis (Izhikevich only, not Hodgkin-Huxley)
# - Laminar proxy field (Gaussian leadfield, no PDE solver)
#
# **Truth Gates:**
# - `physical_amplitude_calibrated=False` (outputs are relative units only)
# - No EEG/MEG/LFP/CSD physical-measurement wording
# - All outputs simulated diagnostic proxies only
#
# **Interpretation Boundary:** This notebook is a computational scaffold for studying network dynamics. Proxy readouts are tools for structural analysis, not evidence of biological mechanism or amplitude.
